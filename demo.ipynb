# %%
from pymongo import MongoClient

# %%
uri = "mongodb+srv://rahulyadavv7000:Yadavrahul7000@cluster0.rtewdtg.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#this is my database
mydb = client["mydatabase"]

# %%
mycol = mydb["myfirstcollection"]

# %%
myfirstrecord = {"fname": "rahul", "lname":"yadav", "address": "delhi"}

# %%
mycol.insert_one(myfirstrecord)
# Out:
# InsertOneResult(ObjectId('65fa247176dd4549cca1ea23'), acknowledged=True)

# %%
mysecondrecord = {"fname": "adeeb", "lname":"saifi", "address": "delhi"}

# %%
mycol.insert_one(mysecondrecord)
# Out:
# InsertOneResult(ObjectId('65fa247176dd4549cca1ea24'), acknowledged=True)

# %%
client.list_database_names()
# Out:
# ['mydatabase', 'sample_mflix', 'admin', 'local']

# %%
multiplerecords = [

    {"fname": "ankit", "lname":"kumar", "address": "delhi"},
    {"fname": "saqib", "lname":"choudhary", "address": "delhi"}, 
    {"fname":"anish", "lname":"kumar", "address": "delhi"},
    {"fname":"munna", "lname":"michael", "address": "delhi"},
    {"fname":"sonu", "lname":"yadav", "address": "delhi"},
     
]

# %%
x = mycol.insert_many(multiplerecords)

# %%
x.inserted_ids
# Out:
# [ObjectId('65fa247176dd4549cca1ea25'),
#  ObjectId('65fa247176dd4549cca1ea26'),
#  ObjectId('65fa247176dd4549cca1ea27'),
#  ObjectId('65fa247176dd4549cca1ea28'),
#  ObjectId('65fa247176dd4549cca1ea29')]

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('65fa06a4691eb9e93dbc7c1b'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa07d2691eb9e93dbc7c1c'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1d'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1e'), 'fname': 'saqib', 'lname': 'choudhary', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1f'), 'fname': 'anish', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c20'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c21'), 'fname': 'abhishek', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea23'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea24'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# ...

# %%
mycol.find_one({"name":"rahul"})

# %%
for x in mycol.find({"lname":"yadav"}):
    print(x)
# Out:
# {'_id': ObjectId('65fa06a4691eb9e93dbc7c1b'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c21'), 'fname': 'abhishek', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea23'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea29'), 'fname': 'sonu', 'lname': 'yadav', 'address': 'delhi'}

# %%
for x in mycol.find().sort("fname"):
    print(x)
# Out:
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c21'), 'fname': 'abhishek', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa07d2691eb9e93dbc7c1c'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea24'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1f'), 'fname': 'anish', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea27'), 'fname': 'anish', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1d'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea25'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c20'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea28'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# ...

# %%
for x in mycol.find().sort("fname", -1):
    print(x)
# Out:
# {'_id': ObjectId('65fa247176dd4549cca1ea29'), 'fname': 'sonu', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1e'), 'fname': 'saqib', 'lname': 'choudhary', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea26'), 'fname': 'saqib', 'lname': 'choudhary', 'address': 'delhi'}
# {'_id': ObjectId('65fa06a4691eb9e93dbc7c1b'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea23'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c20'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea28'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1d'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea25'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# ...

# %%
for x in mycol.find().limit(4):
    print(x)
# Out:
# {'_id': ObjectId('65fa06a4691eb9e93dbc7c1b'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa07d2691eb9e93dbc7c1c'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1d'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1e'), 'fname': 'saqib', 'lname': 'choudhary', 'address': 'delhi'}

# %%
myquery = {"fname" : "sonu"}
newvalue = {"$set":{"fname":"abhishek"}}

# %%
mycol.update_one(myquery, newvalue)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000003'), 'opTime': {'ts': Timestamp(1710892148, 1), 't': 3}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1710892148, 1), 'signature': {'hash': b'$\x7f>D\x00\xba\xe3|\xab\x10{d\xba\xdc!\xe0zh\xcf*', 'keyId': 7348016481642217477}}, 'operationTime': Timestamp(1710892148, 1), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('65fa06a4691eb9e93dbc7c1b'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa07d2691eb9e93dbc7c1c'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1d'), 'fname': 'ankit', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1e'), 'fname': 'saqib', 'lname': 'choudhary', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c1f'), 'fname': 'anish', 'lname': 'kumar', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c20'), 'fname': 'munna', 'lname': 'michael', 'address': 'delhi'}
# {'_id': ObjectId('65fa0c9e691eb9e93dbc7c21'), 'fname': 'abhishek', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea23'), 'fname': 'rahul', 'lname': 'yadav', 'address': 'delhi'}
# {'_id': ObjectId('65fa247176dd4549cca1ea24'), 'fname': 'adeeb', 'lname': 'saifi', 'address': 'delhi'}
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ShapeLab/ZooidsCompositePhysicalizations/master/Zooid_Vis/bin/data/student-dataset.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
#this is my database
mydb = client["mydatabase"]

# %%
mycol2 = mydb["googleplaystore"]

# %%
import json

json.loads(df.T.to_json())
# Out:
# {'0': {'id': 0,
#   'name': 'Kiana Lor',
#   'nationality': 'China',
#   'city': 'Suzhou',
#   'latitude': 31.31,
#   'longitude': 120.62,
#   'gender': 'F',
#   'ethnic.group': None,
#   'age': 22,
#   'english.grade': 3.5,
#   'math.grade': 3.7,
#   'sciences.grade': 3.1,
#   'language.grade': 1.0,
#   'portfolio.rating': 4,
#   'coverletter.rating': 4.0,
#   'refletter.rating': 4},
#  '1': {'id': 1,
#   'name': 'Joshua Lonaker',
#   'nationality': 'United States of America',
#   'city': 'Santa Clarita',
#   'latitude': 34.39,
#   'longitude': -118.54,
#   'gender': 'M',
#   'ethnic.group': None,
#   'age': 22,
#   'english.grade': 2.9,
#   'math.grade': 3.2,
#   'sciences.grade': 3.6,
#   'language.grade': 5.0,
#   'portfolio.rating': 5,
#   'coverletter.rating': 4.0,
#   'refletter.rating': 5},
#  '2': {'id': 2,
#   'name': 'Dakota Blanco',
#   'nationality': 'United States of America',
#   'city': 'Oakland',
#   'latitude': 37.8,
#   'longitude': -122.27,
#   'gender': 'F',
# ...

# %%
#list of records
mycsvfile = list(json.loads(df.T.to_json()).values())

# %%
mycol2.insert_many(mycsvfile)
# Out:
# InsertManyResult([ObjectId('65fa280976dd4549cca1ea2a'), ObjectId('65fa280976dd4549cca1ea2b'), ObjectId('65fa280976dd4549cca1ea2c'), ObjectId('65fa280976dd4549cca1ea2d'), ObjectId('65fa280976dd4549cca1ea2e'), ObjectId('65fa280976dd4549cca1ea2f'), ObjectId('65fa280976dd4549cca1ea30'), ObjectId('65fa280976dd4549cca1ea31'), ObjectId('65fa280976dd4549cca1ea32'), ObjectId('65fa280976dd4549cca1ea33'), ObjectId('65fa280976dd4549cca1ea34'), ObjectId('65fa280976dd4549cca1ea35'), ObjectId('65fa280976dd4549cca1ea36'), ObjectId('65fa280976dd4549cca1ea37'), ObjectId('65fa280976dd4549cca1ea38'), ObjectId('65fa280976dd4549cca1ea39'), ObjectId('65fa280976dd4549cca1ea3a'), ObjectId('65fa280976dd4549cca1ea3b'), ObjectId('65fa280976dd4549cca1ea3c'), ObjectId('65fa280976dd4549cca1ea3d'), ObjectId('65fa280976dd4549cca1ea3e'), ObjectId('65fa280976dd4549cca1ea3f'), ObjectId('65fa280976dd4549cca1ea40'), ObjectId('65fa280976dd4549cca1ea41'), ObjectId('65fa280976dd4549cca1ea42'), ObjectId('65fa280976dd4549cca1
# ...
